// %%
@file:DependsOn("io.github.patbeagan1:legion:0.0.3")

// %%
import io.github.patbeagan1.legion.*

val legion = legion<String>{
    start..{ it.count() }..{println(it)}
}

legion.accept("Hello")
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[13], line 4, column 5: To use contextual declarations, specify the `-Xcontext-receivers` compiler option
// at Cell In[13], line 4, column 5: To use contextual declarations, specify the `-Xcontext-receivers` compiler option
// at Cell In[13], line 4, column 10: Not enough information to infer type variable I
// at Cell In[13], line 4, column 26: Not enough information to infer type variable I
// at Cell In[13], line 7, column 8: Suspend function 'accept' should be called only from a coroutine or another suspend function
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:208)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:80)
// ...

// %% [markdown]
// Turns out this won't work because context parameters are only available with kt 2.2.0
//
// As of writing, the latest version is 2.1.21
